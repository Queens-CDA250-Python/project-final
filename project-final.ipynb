# %% [markdown]
# # Enter Name here:

# %% [markdown]
# Please complete your final project in the space below. Do not forget to explain and interpret the process.
#
# You can find the instructions for the final project here: https://nathanmichalewicz.org/courses/python/assignments/final-project.html
#
# You can find the rubric here: https://nathanmichalewicz.org/courses/python/assignments/project-rubric.html
